# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, join

# %%
#Get files
mypath = 'C:\\Users\\janol\\OneDrive\\Documentos\\DragApp\\KW Landscape English Language\\'

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
#print(onlyfiles)

large_df = pd.DataFrame()                    

for x in onlyfiles:
    df = pd.read_csv(mypath + x, sep='\r\t\n\0', engine='python', skiprows=(0,1), header=None)
    
    #Fix import #1 separate columns
    series = df.squeeze()
    series = series.str.replace('\x00', '', regex=True)
    df = series.str.split("\t", expand=True,)

    #Fix import #2 column names
    new_header = df.iloc[0]
    df = df[1:]
    df.columns = new_header
    df = df.iloc[: , :24]
    #print(df.shape)
    large_df = large_df.append(df)


print(large_df.shape)
#print(large_df.columns)
display(large_df.head())
# Out:
# (63893, 24)
# 0                          Keyword Currency Avg. monthly searches Competition  \
# 1        zendesk free alternatives      USD                   260      Medium
# 2  zendesk open source alternative      USD                    70      Medium
# 3                                      None                  None        None
# 1              zendesk competitors      USD                  1000      Medium
# 2      zendesk competitors gartner      USD                    20        High
#
# 0 Competition (indexed value) Top of page bid (low range)  \
# 1                          47                        4.00
# 2                          64                        6.76
# 3                        None                        None
# 1                          64                       10.00
# 2                          73                        4.32
#
# 0 Top of page bid (high range) Ad impression share Organic impression share  \
# 1                        20.74
# ...

# %%
print(type(large_df))

large_df.to_csv('C:\\Users\\janol\\OneDrive\\Documentos\\DragApp\\KW_Analysis_EN.csv', encoding='utf-8-sig')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.read_csv('C:\\Users\\janol\\OneDrive\\Documentos\\DragApp\\KW_Analysis_EN.csv')
print(df.head())
# Out:
#     \t"
# 0  1\t"
# 1  2\t"
# 2  3\t"
# 3  1\t"
# 4  2\t"
